# %% [markdown]
# ### Dataset Representation Check

# %%
import pandas as pd

# %%
school_list = pd.read_excel('../analysis/data/ncesdata_91F8F27D_cleaned.xlsx')
school_list.head()
# Out:
#    NCES School ID State School ID  NCES District ID State District ID  \
# 0    130012004145     GA-761-0415           1300120            GA-761
# 1    130012002615     GA-761-0505           1300120            GA-761
# 2    130012003541     GA-761-0206           1300120            GA-761
# 3    130012003558     GA-761-1411           1300120            GA-761
# 4    130012000077     GA-761-5066           1300120            GA-761
#
#   Low Grade  High Grade                                School Name  \
# 0        KG          12                  Atlanta Classical Academy
# 1        KG           5  Atlanta Neighborhood Charter - Elementary
# 2        06           8      Atlanta Neighborhood Charter - Middle
# 3        06          12                            B.E.S.T Academy
# 4        PK           5          Barack and Michelle Obama Academy
#
#                  District    County Name        Street Address  ...  \
# 0  Atlanta Public Schools  Fulton County  3260 Northside Dr NW  ...
# ...

# %%
school_list_subset = school_list[(school_list["High Grade"]>5)]
display(school_list_subset)
# Out:
#     NCES School ID State School ID  NCES District ID State District ID  \
# 0     130012004145     GA-761-0415           1300120            GA-761
# 2     130012003541     GA-761-0206           1300120            GA-761
# 3     130012003558     GA-761-1411           1300120            GA-761
# 7     130012001865     GA-761-0182           1300120            GA-761
# 10    130012004174     GA-761-0315           1300120            GA-761
# 12    130012004223     GA-761-1413           1300120            GA-761
# 13    130012003540     GA-761-0106           1300120            GA-761
# 15    130012002290     GA-761-0199           1300120            GA-761
# 16    130012004161     GA-761-0515           1300120            GA-761
# 21    130012003980     GA-761-1410           1300120            GA-761
# 22    130012000017     GA-761-0173           1300120            GA-761
# 23    130012004215     GA-761-1409           1300120            GA-761
# ...

# %%
# get list of all schools in the APS district
# manual check against the kept_files.csv indicates exact matches except for 1 additional school in the APS district (Charles Drew Charter JA/SR Academy)
school_list_subset["School Name"]
# Out:
# 0                             Atlanta Classical Academy
# 2                 Atlanta Neighborhood Charter - Middle
# 3                                       B.E.S.T Academy
# 7                          Benjamin E. Mays High School
# 10                     Booker T. Washington High School
# 12                                   Carver High School
# 13                     Carver High School Early College
# 15                   Centennial Place Academy (Charter)
# 16                   Charles Drew Charter JA/SR Academy
# 21    Coretta Scott King Young Women's Leadership Ac...
# 22                          Crawford Long Middle School
# 23                           D. M. Therrell High School
# 24                         David T Howard Middle School
# 31                       Frederick Douglass High School
# 33                    Hank Aaron New Beginnings Academy
# 36                   Herman J. Russell West End Academy
# 37                               Hillside Conant School
# ...
